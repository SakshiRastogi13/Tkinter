# %%
from tkinter import *
import random
import datetime
import time;
from tkinter import StringVar,ttk,Tk
from tkinter import messagebox
root=Tk()
root.geometry("1500x800")
root.title("Fast Food Restaurant")

F1=Frame(root,width=1500,height=100,border=5,relief="raise")
F1.pack(side=TOP)
L1=Label(F1,font=('arial',60,'bold'),fg='Yellow',bg='Green',text="Fast Food Restaurant")
L1.grid(row=0,column=0)
F2=Frame(root,width=1500,height=700,border=5,relief="raise")
F2.pack(side=BOTTOM)
F3=Frame(F2,width=500,height=700,border=5,relief="raise")
F3.pack(side=LEFT)
F4=Frame(F2,width=500,height=700,border=5,relief="raise")
F4.pack(side=LEFT)
F4_a=Frame(F4,width=500,height=350,border=5,relief="raise")
F4_a.pack(side=TOP)
F4_b=Frame(F4,width=500,height=350,border=5,relief="raise")
F4_b.pack(side=BOTTOM)
F5=Frame(F2,width=500,height=700,border=5,relief="raise")
F5.pack(side=RIGHT)
var1=IntVar()
var2=IntVar()
var3=IntVar()
var4=IntVar()
var5=IntVar()
var6=IntVar()
var7=IntVar()
var8=IntVar()
var9=IntVar()
var10=IntVar()
var11=IntVar()
var12=IntVar()
var13=IntVar()
var14=IntVar()
var15=IntVar()
var16=IntVar()
var17=IntVar()
var18=IntVar()
var19=IntVar()
var20=IntVar()
var21=IntVar()
var22=IntVar()
var23=IntVar()

var1.set(0)
var2.set(0)
var3.set(0)
var4.set(0)
var5.set(0)
var6.set(0)
var7.set(0)
var8.set(0)
var9.set(0)
var10.set(0)
var11.set(0)
var12.set(0)
var13.set(0)
var14.set(0)
var15.set(0)
var16.set(0)
var17.set(0)
var18.set(0)
var19.set(0)
var20.set(0)
var21.set(0)
var22.set(0)
var23.set(0)

varFries=StringVar()
varFries.set("0")

varSalad=StringVar()
varSalad.set("0")

varHamBurger=StringVar()
varHamBurger.set("0")

varOnionRings=StringVar()
varOnionRings.set("0")

varChickenSalad=StringVar()
varChickenSalad.set("0")

varFishSandwich=StringVar()
varFishSandwich.set("0")

varCheeseSandwich=StringVar()
varCheeseSandwich.set("0")

varChickenSandwich=StringVar()
varChickenSandwich.set("0")

varTea=StringVar()
varTea.set("0")

varCoffee=StringVar()
varCoffee.set("0")

varCola=StringVar()
varCola.set("0")

varOrange=StringVar()
varOrange.set("0")

varBottleWater=StringVar()
varBottleWater.set("0")

varVanillaShake=StringVar()
varVanillaShake.set("0")

varStrawberryShake=StringVar()
varStrawberryShake.set("0")

varChocolateShake=StringVar()
varChocolateShake.set("0")

varHash_Brown=StringVar()
varHash_Brown.set("0")

varToastedBagel=StringVar()
varToastedBagel.set("0")

varPancakesSyrup=StringVar()
varPancakesSyrup.set("0")

varPineappleStick=StringVar()
varPineappleStick.set("0")

varChocolateMuffin=StringVar()
varChocolateMuffin.set("0")

varChange=StringVar()
varChange.set("0")

varTax=StringVar()
varTax.set("0")

varSubTotal=StringVar()
varSubTotal.set("0")

varTotal=StringVar()
varTotal.set("0")

vara=StringVar()
vara.set("0")

def iExit():
    qExit=messagebox.askyesno("Fast Food!!","Do you want to exit?")
    if qExit>0:
        root.destroy()
        return
    
def Reset():
    varFries.set("0")
    varSalad.set("0")
    varHamBurger.set("0")
    varOnionRings.set("0")
    varChickenSalad.set("0")
    varFishSandwich.set("0")
    varCheeseSandwich.set("0")
    varChickenSandwich.set("0")
    varTea.set("0")
    varCoffee.set("0")
    varCola.set("0")
    varOrange.set("0")
    varBottleWater.set("0")
    varVanillaShake.set("0")
    varStrawberryShake.set("0")
    varChocolateShake.set("0")
    varHash_Brown.set("0")
    varToastedBagel.set("0")
    varPancakesSyrup.set("0")
    varPineappleStick.set("0")
    varChocolateMuffin.set("0")
    varChange.set("0")
    varTax.set("0")
    varSubTotal.set("0")
    varTotal.set("0")
    vara.set("0")
    #text_Fries.configure(state=DISABLED)
    #text_Salad.configure(state="disabled")
    #text_Hamburger.configure(state="disabled")
    #text_OnionRings.configure(state="disabled")
    #text_ChickenSalad.configure(state="disabled")
    #text_FishSandwich.configure(state="disabled")
    #text_CheeseSandwich.configure(state="disabled")
    #text_ChickenSandwich.configure(state="disabled")
    #text_Tea.configure(state="disabled")
    #text_Coffee.configure(state="disabled")
    #text_Cola.configure(state="disabled")
    #text_Orange.configure(state="disabled")
    #text_BottleWater.configure(state="disabled")
    #text_VanillaShake.configure(state="disabled")
    #text_StrawberryShake.configure(state="disabled")
    #text_ChocolateShake.configure(state="disabled")
    #text_Hash_Brown.configure(state="disabled")
    #text_ToastedBagel.configure(state="disabled")
    #text_PancakesSyrup.configure(state="disabled")
    #text_PineappleStick.configure(state="disabled")
    #text_ChocolateMuffin.configure(state="disabled")
    #text_Change.configure(state="disabled")
    #text_Tax.configure(state="disabled")
    #text_SubTotal.configure(state="disabled")
    #text_Total.configure(state="disabled")
    #text_a.configure(state="disabled")
def Check_Fries():
    if(var1.get()==1):
        text_Fries.configure(state=NORMAL)
        varFries.set("")
    elif(var1.get()==0):
        text_Fries.configure(state=DISABLED)
        varFries.set("0")
def Check_Salad():
    if(var2.get()==1):
        text_Salad.configure(state=NORMAL)
        varSalad.set("")
    elif(var2.get()==0):
        text_Salad.configure(state=DISABLED)
        varSalad.set("0")
def Check_HamBurger():
    if(var3.get()==1):
        text_HamBurger.configure(state=NORMAL)
        varHamBurger.set("")
    elif(var3.get()==0):
        text_HamBurger.configure(state=DISABLED)
        varHamBurger.set("0")
def Check_OnionRings():
    if(var4.get()==1):
        text_OnionRings.configure(state=NORMAL)
        varOnionRings.set("")
    elif(var4.get()==0):
        text_OnionRings.configure(state=DISABLED)
        varOnionRings.set("0")
def Check_ChickenSalad():
    if(var5.get()==1):
        text_ChickenSalad.configure(state=NORMAL)
        varChickenSalad.set("")
    elif(var5.get()==0):
        text_ChickenSalad.configure(state=DISABLED)
        varChickenSalad.set("0")
def Check_FishSandwich():
    if(var6.get()==1):
        text_FishSandwich.configure(state=NORMAL)
        varFishSandwich.set("")
    elif(var6.get()==0):
        text_FishSandwich.configure(state=DISABLED)
        varFishSandwich.set("0")
def Check_CheeseSandwich():
    if(var7.get()==1):
        text_CheeseSandwich.configure(state=NORMAL)
        varCheeseSandwich.set("")
    elif(var7.get()==0):
        text_CheeseSandwich.configure(state=DISABLED)
        varCheeseSandwich.set("0")
def Check_ChickenSandwich():
    if(var8.get()==1):
        text_ChickenSandwich.configure(state=NORMAL)
        varChickenSandwich.set("")
    elif(var8.get()==0):
        text_ChickenSandwich.configure(state=DISABLED)
        varChickenSandwich.set("0")
def Check_Tea():
    if(var9.get()==1):
        text_Tea.configure(state=NORMAL)
        varTea.set("")
    elif(var9.get()==0):
        text_Tea.configure(state=DISABLED)
        varTea.set("0")
def Check_Coffee():
    if(var10.get()==1):
        text_Coffee.configure(state=NORMAL)
        varCoffee.set("")
    elif(var10.get()==0):
        text_Coffee.configure(state=DISABLED)
        varCoffee.set("0")
def Check_Cola():
    if(var11.get()==1):
        text_Cola.configure(state=NORMAL)
        varCola.set("")
    elif(var11.get()==0):
        texCola.set("0")
def Check_Orange():
    if(var12.get()==1):
        text_Orange.configure(state=NORMAL)
        varOrange.set("")
    elif(var12.get()==0):
        text_Orange.configure(state=DISABLED)
        varOrange.set("0")
def Check_BottleWater():
    if(var13.get()==1):
        text_BottleWater.configure(state=NORMAL)
        varBottleWater.set("")
    elif(var13.get()==0):
        text_BottleWater.configure(state=DISABLED)
        varBottleWater.set("0")
def Check_VanillaShake():
    if(var14.get()==1):
        text_VanillaShake.configure(state=NORMAL)
        varVanillaShake.set("")
    elif(var14.get()==0):
        text_VanillaShake.configure(state=DISABLED)
        varVanillaShake.set("0")
def Check_StrawberryShake():
    if(var15.get()==1):
        text_StrawberryShake.configure(state=NORMAL)
        varStrawberryShake.set("")
    elif(var15.get()==0):
        text_StrawberryShake.configure(state=DISABLED)
        varStrawberryShake.set("0")
def Check_ChocolateShake():
    if(var16.get()==1):
        text_ChocolateShake.configure(state=NORMAL)
        varChocolateShake.set("")
    elif(var16.get()==0):
        text_ChocolateShake.configure(state=DISABLED)
        varChocolateShake.set("0")
def Check_HashBrown():
    if(var17.get()==1):
        text_HashBrown.configure(state=NORMAL)
        varHashBrown.set("")
    elif(var17.get()==0):
        text_HashBrown.configure(state=DISABLED)
        varHashBrown.set("0")
def Check_ToastedBagel():
    if(var18.get()==1):
        text_ToastedBagel.configure(state=NORMAL)
        varToastedBagel.set("")
    elif(var18.get()==0):
        text_ToastedBagel.configure(state=DISABLED)
        varToastedBagel.set("0")
def Check_PancakesSyrup():
    if(var19.get()==1):
        text_PancakesSyrup.configure(state=NORMAL)
        varPancakesSyrup.set("")
    elif(var19.get()==0):
        text_PancakesSyrup.configure(state=DISABLED)
        varPancakesSyrup.set("0")
def Check_PineappleStick():
    if(var20.get()==1):
        text_PineappleStick.configure(state=NORMAL)
        varPineappleStick.set("")
    elif(var20.get()==0):
        text_PineappleStick.configure(state=DISABLED)
        varPineappleStick.set("0")
def Check_ChocolateMuffin():
    if(var21.get()==1):
        textChocolateMuffin.configure(state=NORMAL)
        varChocolateMuffin.set("")
    elif(var21.get()==0):
        texChocolateMuffin.set("0")
def Cost():
    m1=float(varFries.get())
    m2=float(varSalad.get())
    m3=float(varHamBurger.get())
    m4=float(varOnionRings.get())
    m5=float(varChickenSalad.get())
    m6=float(varFishSandwich.get())
    m7=float(varCheeseSandwich.get())
    m8=float(varChickenSandwich.get())
    m9=float(varTea.get())
    m10=float(varCoffee.get())
    m11=float(varCola.get())
    m12=float(varOrange.get())
    m13=float(varBottleWater.get())
    m14=float(varVanillaShake.get())
    m15=float(varStrawberryShake.get())
    m16=float(varChocolateShake.get())
    m17=float(varHash_Brown.get())
    m18=float(varToastedBagel.get())
    m19=float(varPancakesSyrup.get())
    m20=float(varPineappleStick.get())
    m21=float(varChocolateMuffin.get())
    #m22=float(vara.get())
    
    Total1=((m1*1.70)+(m2*2.10)+(m3*3.30)+(m4*1.30)+(m5*3.50))
    Total2=((m6*3.60)+(m7*3.40)+(m8*3.60))
    Total3=((m9*1.50)+(m10*1.59)+(m11*1.30)+(m12*1.20)+(m13*0.99))
    Total4=((m14*2.10)+(m15*2.50)+(m16*3.00))
    Total5=((m17*1.50)+(m18*1.50)+(m19*1.50)+(m20*1.50)+(m21*1.50))
    cost=(Total1+Total2+Total3+Total4+Total5)
    Tax=(cost*3.4)/100
    varTax.set(Tax)
    varSubTotal.set(cost)
    varTotal.set(cost+Tax)
    #varChange=(m22-(cost+Tax))
    

    
L2=Label(F3,font=('arial',40,'bold'),text="Snacks",fg="Purple")
L2.grid(row=0,column=0) 
Fries=Checkbutton(F3,text="French Fries  $1.70",font=('arial',20,'bold'),variable=var1,fg="Red",command=Check_Fries)
Fries.grid(row=1,column=0,sticky=W)
text_Fries=Entry(F3,width=15,border=4,textvariable=varFries)
text_Fries.grid(row=1,column=1)
Salad=Checkbutton(F3,text="Salad              $2.10",font=('arial',20,'bold'),variable=var2,fg="Red",command=Check_Salad)
Salad.grid(row=2,column=0,sticky=W)
text_Salad=Entry(F3,width=15,border=4,textvariable=varSalad)
text_Salad.grid(row=2,column=1)
HamBurger=Checkbutton(F3,text="HamBurger    $3.30",font=('arial',20,'bold'),variable=var3,fg="Red",command=Check_HamBurger)
HamBurger.grid(row=3,column=0,sticky=W)
text_HamBurger=Entry(F3,width=15,border=4,textvariable=varHamBurger)
text_HamBurger.grid(row=3,column=1)
OnionRings=Checkbutton(F3,text="OnionRings    $1.30",font=('arial',20,'bold'),variable=var4,fg="Red",command=Check_OnionRings)
OnionRings.grid(row=4,column=0,sticky=W)
text_OnionRings=Entry(F3,width=15,border=4,textvariable=varOnionRings)
text_OnionRings.grid(row=4,column=1)
ChickenSalad=Checkbutton(F3,text="ChickenSalad  $3.50",font=('arial',20,'bold'),variable=var5,fg="Red",command=Check_ChickenSalad)
ChickenSalad.grid(row=5,column=0,sticky=W)
text_ChickenSalad=Entry(F3,width=15,border=4,textvariable=varChickenSalad)
text_ChickenSalad.grid(row=5,column=1)
L3=Label(F3,text="\nSandwich\n",font=('arial',40,'bold'),fg='Purple')
L3.grid(row=6,column=0)
FishSandwich=Checkbutton(F3,text="Fish Sandwich \t\t $3.60",font=('arial',20,'bold'),variable=var6,fg="Red",command=Check_FishSandwich)
FishSandwich.grid(row=7,column=0,sticky=W)
text_FishSandwich=Entry(F3,width=15,border=4,textvariable=varFishSandwich)
text_FishSandwich.grid(row=7,column=1)
CheeseSandwich=Checkbutton(F3,text="Cheese Sandwich \t $3.40",font=('arial',20,'bold'),variable=var7,fg="Red",command=Check_CheeseSandwich)
CheeseSandwich.grid(row=8,column=0,sticky=W)
text_CheeseSandwich=Entry(F3,width=15,border=4,textvariable=varCheeseSandwich)
text_CheeseSandwich.grid(row=8,column=1)
ChickenSandwich=Checkbutton(F3,text="Chicken Sandwich \t $3.60",font=('arial',20,'bold'),variable=var8,fg="Red",command=Check_ChickenSandwich)
ChickenSandwich.grid(row=9,column=0,sticky=W)
text_ChickenSandwich=Entry(F3,width=15,border=4,textvariable=varChickenSandwich)
text_ChickenSandwich.grid(row=9,column=1)

L4=Label(F5,text="Drinks",font=('arial',40,'bold'),fg='Purple')
L4.grid(row=0,column=0)
Tea=Checkbutton(F5,text="Tea \t       $1.50",font=('arial',20,'bold'),variable=var9,fg="Red",command=Check_Tea)
Tea.grid(row=1,column=0,sticky=W)
text_Tea=Entry(F5,width=15,border=4,textvariable=varTea)
text_Tea.grid(row=1,column=1)
Coffee=Checkbutton(F5,text="Coffee \t       $1.59",font=('arial',20,'bold'),variable=var10,fg="Red",command=Check_Coffee)
Coffee.grid(row=2,column=0,sticky=W)
text_Coffee=Entry(F5,width=15,border=4,textvariable=varCoffee)
text_Coffee.grid(row=2,column=1)
Cola=Checkbutton(F5,text="Cola \t       $1.30",font=('arial',20,'bold'),variable=var11,fg="Red",command=Check_Cola)
Cola.grid(row=3,column=0,sticky=W)
text_Cola=Entry(F5,width=15,border=4,textvariable=varCola)
text_Cola.grid(row=3,column=1)
Orange=Checkbutton(F5,text="Orange \t       $1.20",font=('arial',20,'bold'),variable=var12,fg="Red",command=Check_Orange)
Orange.grid(row=4,column=0,sticky=W)
text_Orange=Entry(F5,width=15,border=4,textvariable=varOrange,)
text_Orange.grid(row=4,column=1)
BottleWater=Checkbutton(F5,text="Bottle Water  $0.99",font=('arial',20,'bold'),variable=var13,fg="Red",command=Check_BottleWater)
BottleWater.grid(row=5,column=0,sticky=W)
text_BottleWater=Entry(F5,width=15,border=4,textvariable=varBottleWater)
text_BottleWater.grid(row=5,column=1)
L5=Label(F5,text="\nShakes\n",font=('arial',40,'bold'),fg='Purple')
L5.grid(row=7,column=0)
VanillaShake=Checkbutton(F5,text="Vanilla Shake \t  $2.10",font=('arial',20,'bold'),variable=var14,fg="Red",command=Check_VanillaShake)
VanillaShake.grid(row=8,column=0,sticky=W)
text_VanillaShake=Entry(F5,width=15,border=4,textvariable=varVanillaShake)
text_VanillaShake.grid(row=8,column=1)
StrawberryShake=Checkbutton(F5,text="Strawberry Shake \t  $2.50",font=('arial',20,'bold'),variable=var15,fg="Red",command=Check_StrawberryShake)
StrawberryShake.grid(row=9,column=0,sticky=W)
text_StrawberryShake=Entry(F5,width=15,border=4,textvariable=varStrawberryShake)
text_StrawberryShake.grid(row=9,column=1)
ChocolateShake=Checkbutton(F5,text="Chocolate Shake \t  $3.00",font=('arial',20,'bold'),variable=var16,fg="Red",command=Check_ChocolateShake)
ChocolateShake.grid(row=10,column=0,sticky=W)
text_ChocolateShake=Entry(F5,width=15,border=4,textvariable=varChocolateShake)
text_ChocolateShake.grid(row=10,column=1)
L5=Label(F4_a,text="Desserts",font=('arial',40,'bold'),fg='Purple')
L5.grid(row=11,column=0)
Hash_Brown=Checkbutton(F4_a,text="Hash Brown \t       $1.50",font=('arial',20,'bold'),variable=var17,fg="Red",command=Check_HashBrown)
Hash_Brown.grid(row=12,column=0,sticky=W)
text_Hash_Brown=Entry(F4_a,width=15,border=4,textvariable=varHash_Brown)
text_Hash_Brown.grid(row=12,column=1)
ToastedBagel=Checkbutton(F4_a,text="ToastedBagel \t       $1.50",font=('arial',20,'bold'),variable=var18,fg="Red",command=Check_ToastedBagel)
ToastedBagel.grid(row=13,column=0,sticky=W)
text_ToastedBagel=Entry(F4_a,width=15,border=4,textvariable=varToastedBagel)
text_ToastedBagel.grid(row=13,column=1)
PancakesSyrup=Checkbutton(F4_a,text="Pancakes Syrup \t       $1.50",font=('arial',20,'bold'),variable=var19,fg="Red",command=Check_PancakesSyrup)
PancakesSyrup.grid(row=14,column=0,sticky=W)
text_PancakesSyrup=Entry(F4_a,width=15,border=4,textvariable=varPancakesSyrup)
text_PancakesSyrup.grid(row=14,column=1)
PineappleStick=Checkbutton(F4_a,text="Pineapple Stick \t       $1.50",font=('arial',20,'bold'),variable=var20,fg="Red",command=Check_PineappleStick)
PineappleStick.grid(row=15,column=0,sticky=W)
text_PineappleStick=Entry(F4_a,width=15,border=4,textvariable=varPineappleStick)
text_PineappleStick.grid(row=15,column=1)
ChocolateMuffin=Checkbutton(F4_a,text="Chocolate Muffin \t       $1.50",font=('arial',20,'bold'),variable=var21,fg="Red",command=Check_ChocolateMuffin)
ChocolateMuffin.grid(row=16,column=0,sticky=W)
text_ChocolateMuffin=Entry(F4_a,width=15,border=4,textvariable=varChocolateMuffin)
text_ChocolateMuffin.grid(row=16,column=1)
L6=Label(F4_b,text="Cash Paid",font=('arial',15,'bold'),fg='Green')
L6.grid(row=17,column=0)
L7=Label(F4_b,text="Change",font=('arial',15,'bold'),fg='Green')
L7.grid(row=17,column=1)
text_Change=Entry(F4_b,width=15,border=4,textvariable=varChange)
text_Change.grid(row=17,column=2)
L7=Label(F4_b,text=" Tax",font=('arial',15,'bold'),fg='Green')
L7.grid(row=18,column=1)
text_Tax=Entry(F4_b,width=15,border=4,textvariable=varTax)
text_Tax.grid(row=18,column=2)
text_a=Entry(F4_b,width=15,border=4,textvariable=vara)
text_a.grid(row=19,column=0)
L7=Label(F4_b,text="SubTotal",font=('arial',15,'bold'),fg='Green')
L7.grid(row=19,column=1)
text_SubTotal=Entry(F4_b,width=15,border=4,textvariable=varSubTotal)
text_SubTotal.grid(row=19,column=2)
L7=Label(F4_b,text="Total",font=('arial',15,'bold'),fg='Green')
L7.grid(row=20,column=1)
text_Total=Entry(F4_b,width=15,border=4,textvariable=varTotal)
text_Total.grid(row=20,column=2)
B1=Button(F4_b,text="Total",font=('arial',15,'bold'),width=10,border=2,bg="Black",fg="Pink",command=Cost)
B1.grid(row=21,column=0)
B2=Button(F4_b,text="Reset",font=('arial',15,'bold'),width=10,border=2,bg="Black",fg="Pink",command=Reset)
B2.grid(row=21,column=1)
B2=Button(F4_b,text="Exit ",font=('arial',15,'bold'),width=10,border=2,bg="Black",fg="Pink",command=iExit)
B2.grid(row=21,column=2)
root.mainloop()
